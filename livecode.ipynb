# %%
t_f = 12;

K = 3.0;

M = 14;
N = 10000;
L = 10
dX = L / M;
dT = t_f / N;

@show (dX^2 / K, dT)

x_grid = 0:dX:0
print(x_grid)
# Out:
# (dX ^ 2 / K, dT) = (0.17006802721088435, 0.0012)
# 0.0:0.7142857142857143:0.0
